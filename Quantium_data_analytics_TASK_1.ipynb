# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
#transaction dataset
path1="/content/drive/MyDrive/QUANTIUM DATA ANALYTICS/QVI_transaction_data.xlsx"
transaction = pd.read_excel(path1)

# %%
transaction.head()
# Out:
#     DATE  STORE_NBR  LYLTY_CARD_NBR  TXN_ID  PROD_NBR  \
# 0  43390          1            1000       1         5
# 1  43599          1            1307     348        66
# 2  43605          1            1343     383        61
# 3  43329          2            2373     974        69
# 4  43330          2            2426    1038       108
#
#                                   PROD_NAME  PROD_QTY  TOT_SALES
# 0    Natural Chip        Compny SeaSalt175g         2        6.0
# 1                  CCs Nacho Cheese    175g         3        6.3
# 2    Smiths Crinkle Cut  Chips Chicken 170g         2        2.9
# 3    Smiths Chip Thinly  S/Cream&Onion 175g         5       15.0
# 4  Kettle Tortilla ChpsHny&Jlpno Chili 150g         3       13.8
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['DATE'].plot(kind='hist', bins=20, title='DATE')
# ...

# %%
#customer analytics
path2="/content/drive/MyDrive/QUANTIUM DATA ANALYTICS/QVI_purchase_behaviour.csv"
customer = pd.read_csv(path2)
customer.head()
# Out:
#    LYLTY_CARD_NBR               LIFESTAGE PREMIUM_CUSTOMER
# 0            1000   YOUNG SINGLES/COUPLES          Premium
# 1            1002   YOUNG SINGLES/COUPLES       Mainstream
# 2            1003          YOUNG FAMILIES           Budget
# 3            1004   OLDER SINGLES/COUPLES       Mainstream
# 4            1005  MIDAGE SINGLES/COUPLES       Mainstream
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_21['LYLTY_CARD_NBR'].plot(kind='hist', bins=20, title='LYLTY_CARD_NBR')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# ...

# %% [markdown]
# **TRANSACTION**

# %%
#Creating and interpreting high-level summaries of the data
transaction.shape
# Out:
# (264836, 8)

# %%
transaction.describe()
# Out:
#                 DATE     STORE_NBR  LYLTY_CARD_NBR        TXN_ID  \
# count  264836.000000  264836.00000    2.648360e+05  2.648360e+05
# mean    43464.036260     135.08011    1.355495e+05  1.351583e+05
# std       105.389282      76.78418    8.057998e+04  7.813303e+04
# min     43282.000000       1.00000    1.000000e+03  1.000000e+00
# 25%     43373.000000      70.00000    7.002100e+04  6.760150e+04
# 50%     43464.000000     130.00000    1.303575e+05  1.351375e+05
# 75%     43555.000000     203.00000    2.030942e+05  2.027012e+05
# max     43646.000000     272.00000    2.373711e+06  2.415841e+06
#
#             PROD_NBR       PROD_QTY      TOT_SALES
# count  264836.000000  264836.000000  264836.000000
# mean       56.583157       1.907309       7.304200
# std        32.826638       0.643654       3.083226
# min         1.000000       1.000000       1.500000
# 25%        28.000000       2.000000       5.400000
# 50%        56.000000       2.000000       7.400000
# ...

# %% [markdown]
# **Checking for data types**

# %%
transaction.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 264836 entries, 0 to 264835
# Data columns (total 8 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   DATE            264836 non-null  int64
#  1   STORE_NBR       264836 non-null  int64
#  2   LYLTY_CARD_NBR  264836 non-null  int64
#  3   TXN_ID          264836 non-null  int64
#  4   PROD_NBR        264836 non-null  int64
#  5   PROD_NAME       264836 non-null  object
#  6   PROD_QTY        264836 non-null  int64
#  7   TOT_SALES       264836 non-null  float64
# dtypes: float64(1), int64(6), object(1)
# memory usage: 16.2+ MB

# %% [markdown]
# **Checking for null values**

# %%
transaction.isnull().sum()
# Out:
# DATE              0
# STORE_NBR         0
# LYLTY_CARD_NBR    0
# TXN_ID            0
# PROD_NBR          0
# PROD_NAME         0
# PROD_QTY          0
# TOT_SALES         0
# dtype: int64

# %% [markdown]
# **Outlier detection**

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#display TOT_SALES as it is float type
sns.displot(transaction.TOT_SALES, kde=True)

# %%
#checking the mean value of total sales
numeric=transaction.select_dtypes(['float','int'])
numeric.head()
# Out:
#     DATE  STORE_NBR  LYLTY_CARD_NBR  TXN_ID  PROD_NBR  PROD_QTY  TOT_SALES
# 0  43390          1            1000       1         5         2        6.0
# 1  43599          1            1307     348        66         3        6.3
# 2  43605          1            1343     383        61         2        2.9
# 3  43329          2            2373     974        69         5       15.0
# 4  43330          2            2426    1038       108         3       13.8

# %%
#mean can be taken 8 or 9 but not more than 10 as it has the chance of producing error
x=numeric[numeric['TOT_SALES']<8.000]

# %%
sns.displot(x.TOT_SALES,kde=True)
#from 1-8, there is no evidence of having outliers as there are multiple values being located

# %%
sns.boxplot(x.TOT_SALES)
#there are no outliers in the dataset
# Out:
# <Axes: ylabel='TOT_SALES'>
